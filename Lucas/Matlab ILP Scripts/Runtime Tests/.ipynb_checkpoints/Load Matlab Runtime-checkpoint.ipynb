# %%
from scipy.io import loadmat
import pickle

# %%
with open('grobner_times_all.dict', 'rb') as f:
    example = pickle.load(f)
print(example)
# Out:
# {2: {4: {1: [(['1', '0', '2'], True, 0.008565573770491802), (['1', '0', '2'], True, 0.007042253521126761), (['1', '0', '2'], True, 0.006329113924050633), (['1', '0', '2'], True, 0.006024096385542169), (['1', '0', '2'], True, 0.006060606060606061), (['0', '3', '2'], True, 0.005917159763313609), (['0', '3', '2'], True, 0.006349206349206349), (['0', '3', '2'], True, 0.005934718100890208), (['0', '3', '2'], True, 0.005970149253731343), (['0', '3', '2'], True, 0.0058823529411764705), (['1', '3', '2'], True, 0.0058823529411764705), (['1', '3', '2'], True, 0.005934718100890208), (['1', '3', '2'], True, 0.006024096385542169), (['1', '3', '2'], True, 0.00641744548286604), (['1', '3', '2'], True, 0.006097560975609756), (['1', '3', '2'], True, 0.005970149253731343), (['1', '3', '2'], True, 0.0058997050147492625), (['1', '3', '2'], True, 0.0058997050147492625), (['1', '3', '2'], True, 0.0058997050147492625), (['1', '3', '2'], True, 0.005917159763313609), (['0', '3', '2'], True, 0.006644518272425249), (['0', '3', '2'], True, 0.0058997050147492625), (['0', '3', '2'], True, 0.006711409395973154), (['0', '3', '2'], True, 0.007462686567164179), (['0', '3', '2'], True, 0.006557377049180328), (['1', '0', '2'], True, 0.006042296072507553), (['1', '0', '2'], True, 0.005988023952095809), (['1', '0', '2'], True, 0.005917159763313609), (['1', '0', '2'], True, 0.006006006006006006), (['1', '0', '2'], True, 0.005934718100890208), (['0', '3', '2'], True, 0.006006006006006006), (['0', '3', '2'], True, 0.005865102639296188), (['0', '3', '2'], True, 0.0058823529411764705), (['0', '3', '2'], True, 0.005917159763313609), (['0', '3', '2'], True, 0.006024096385542169), (['1', '0', '2'], True, 0.0058823529411764705), (['1', '0', '2'], True, 0.005917159763313609), (['1', '0', '2'], True, 0.005934718100890208), (['1', '0', '2'], True, 0.0058997050147492625), (['1', '0', '2'], True, 0.0058997050147492625), (['1', '3', '2'], True, 0.005865102639296188), (['1', '3', '2'], True, 0.0058997050147492625), (['1', '3', '2'], True, 0.0058823529411764705), (['1', '3', '2'], True, 0.005917159763313609), (['1', '3', '2'], True, 0.006389776357827476), (['1', '3', '2'], True, 0.006134969325153374), (['1', '3', '2'], True, 0.006153846153846154), (['1', '3', '2'], True, 0.006024096385542169), (['1', '3', '2'], True, 0.005952380952380952), (['1', '3', '2'], True, 0.005952380952380952), (['1', '0', '2'], True, 0.005865102639296188), (['1', '0', '2'], True, 0.005952380952380952), (['1', '0', '2'], True, 0.005952380952380952), (['1', '0', '2'], True, 0.0058823529411764705), (['1', '0', '2'], True, 0.005865102639296188), (['1', '3', '2'], True, 0.005934718100890208), (['1', '3', '2'], True, 0.006578947368421052), (['1', '3', '2'], True, 0.005865102639296188), (['1', '3', '2'], True, 0.006172839506172839), (['1', '3', '2'], True, 0.005934718100890208), (['1', '3', '2'], True, 0.005865102639296188), (['1', '3', '2'], True, 0.006802721088435374), (['1', '3', '2'], True, 0.0058823529411764705), (['1', '3', '2'], True, 0.0058823529411764705), (['1', '3', '2'], True, 0.0058309037900874635), (['1', '0', '2'], True, 0.005934718100890208), (['1', '0', '2'], True, 0.00881578947368421), (['1', '0', '2'], True, 0.006756756756756757), (['1', '0', '2'], True, 0.0060790273556231), (['1', '0', '2'], True, 0.0076045627376425855), (['0', '3', '2'], True, 0.006349206349206349), (['0', '3', '2'], True, 0.005970149253731343), (['0', '3', '2'], True, 0.0058823529411764705), (['0', '3', '2'], True, 0.005899705014749268), (['0', '3', '2'], True, 0.005988023952095809), (['1', '0', '3'], True, 0.005917159763313609), (['1', '0', '3'], True, 0.0058823529411764705), (['1', '0', '3'], True, 0.0058997050147492625), (['1', '0', '3'], True, 0.006292834890965731), (['1', '0', '3'], True, 0.005917159763313609), (['1', '0', '2'], True, 0.005917159763313609), (['1', '0', '2'], True, 0.0058997050147492625), (['1', '0', '2'], True, 0.005917159763313609), (['1', '0', '2'], True, 0.005934718100890208), (['1', '0', '2'], True ...

# %%
mat = loadmat('matlab_runtime.mat')

# %%
data = mat['tests'][0]

# %%
print(data[0])
# Out:
# [[array([[7]], dtype=uint8) array([[3]], dtype=uint8)
#   array(['0212211,1000002,1202212,1201122,1112220,1021002,0010011,1000211'],
#       dtype='<U63')
#   array([[1]], dtype=uint8)
#   array([[0.14238113, 0.13431597, 0.13511044, 0.13299778, 0.14787225]])]]

# %%
d = data[0][0]
R = d[4][0]
print(R)
# Out:
# [0.14238113 0.13431597 0.13511044 0.13299778 0.14787225]

# %%
print(mat['tests'][0])
# Out:
# [array([[array([[7]], dtype=uint8), array([[3]], dtype=uint8),
#         array(['0212211,1000002,1202212,1201122,1112220,1021002,0010011,1000211'],
#       dtype='<U63'),
#         array([[1]], dtype=uint8),
#         array([[0.14238113, 0.13431597, 0.13511044, 0.13299778, 0.14787225]])]],
#       dtype=object)
#  array([[array([[7]], dtype=uint8), array([[3]], dtype=uint8),
#         array(['1120220,0112201,0220220,2211012,0110001,2100011,1022101,0220112'],
#       dtype='<U63'),
#         array([[1]], dtype=uint8),
#         array([[0.13515893, 0.13533722, 0.13909303, 0.14014138, 0.13698428]])]],
#       dtype=object)
#  array([[array([[7]], dtype=uint8), array([[3]], dtype=uint8),
#         array(['1100121,0110022,0100201,0212120,2022101,2120221,0220020,2110211'],
#       dtype='<U63'),
#         array([[1]], dtype=uint8),
#         array([[0.13681744, 0.13629642, 0.13962458, 0.13600128, 0.13719419]])]],
#       dtype=object)
#  ...
#  array([[array([[10]], dtype=uint8), array([[2]], dtype=uint8),
#         array(['1001110000,0101110010,1101001010,0101100011,0101000101,1010111000,0110101111'],
#       dtype='<U76'),
#         array([[0]], dtype=uint8),
#         array([[0.13407956, 0.140276  , 0.13180246, 0.13595791, 0.13283244]])]],
#       dtype=object)
#  array([[array([[10]], dtype=uint8), array([[2]], dtype=uint8),
#         array(['1001101100,1110101110,0010010101,0111000101,0010001011,0111111001,1110101001'],
#       dtype='<U76'),
#         array([[0]], dtype=uint8),
#         array([[0.13206357, 0.12929075, 0.13501949, 0.13453642, 0.13642442]])]],
#       dtype=object)
#  array([[array([[10]], dtype=uint8), array([[2]], dtype=uint8),
#         array(['0011101001,0110011011,1001111111,0001011011,0111001111,0110000010,0101001111'],
#       dtype='<U76'),
#         array([[0]], dtype=uint8),
#         array([[0.13138143, 0.13232829, 0.13113448, 0.13112364, 0.13141787]])]],
#       dtype=object)]

# %%
def parseData(filename):
    mat = loadmat(filename)
    data = mat['tests'][0]
    ILP_times = {}
    for d in data:
        d = d[0]
        As = list(ILP_times.keys())
        k = d[0][0][0]
        a = d[1][0][0]
        R = d[2][0]
        R = R.split(',')
        isResolving = d[3][0][0]
        times = d[4][0]
        if a in As:
            ks = list(ILP_times[a].keys())
            for time in times:
                if k in ks:
                    ILP_times[a][k].append((R,isResolving,time))
                else:
                    ILP_times[a][k] = [(R,isResolving,time)]
        else:
            ILP_times[a] = {}
            for time in times:
                if k in list(ILP_times[a].keys()):
                    ILP_times[a][k].append((R,isResolving,time))
                else:
                    ILP_times[a][k] = [(R,isResolving,time)]
    return ILP_times

# %%
filename = 'matlab_runtime.mat'
ILP_times = parseData(filename)

# %%
with open('ILP_times_all.dict','wb') as f:
    pickle.dump(ILP_times,f)
# Out:
# {3: {7: [(['0212211', '1000002', '1202212', '1201122', '1112220', '1021002', '0010011', '1000211'], 1, 0.1423811322186665), (['0212211', '1000002', '1202212', '1201122', '1112220', '1021002', '0010011', '1000211'], 1, 0.1343159700450601), (['0212211', '1000002', '1202212', '1201122', '1112220', '1021002', '0010011', '1000211'], 1, 0.13511043971697845), (['0212211', '1000002', '1202212', '1201122', '1112220', '1021002', '0010011', '1000211'], 1, 0.13299777681003863), (['0212211', '1000002', '1202212', '1201122', '1112220', '1021002', '0010011', '1000211'], 1, 0.14787224879489372), (['1120220', '0112201', '0220220', '2211012', '0110001', '2100011', '1022101', '0220112'], 1, 0.13515892706238364), (['1120220', '0112201', '0220220', '2211012', '0110001', '2100011', '1022101', '0220112'], 1, 0.13533721593492937), (['1120220', '0112201', '0220220', '2211012', '0110001', '2100011', '1022101', '0220112'], 1, 0.13909302764019618), (['1120220', '0112201', '0220220', '2211012', '0110001', '2100011', '1022101', '0220112'], 1, 0.1401413782573106), (['